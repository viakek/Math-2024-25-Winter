# %% [markdown]
# <a href="https://colab.research.google.com/github/viakek/Math-2024-25-Winter/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 18. Functions
#
# 1. Draw in a single Geogebra notebook the following functions:
#    - $f(x) = x^2$
#    - $g(x) = \sqrt{x}$
#    - $h(x) = \frac{1}{x}$
#    - $j(x) = \sin(x)$
#
# Find value of all the above functions at $x = 2$.
#
# 1. **For f(x) = x^2:**
# $$
# f(2) = 2^2 = 4.
# $$
#
# 2. **For g(x) = √x:**
# $$
# g(2) = \sqrt{2} \approx 1.414.
# $$
#
# 3. **For h(x) = 1/x:**
# $$
# h(2) = \frac{1}{2} = 0.5.
# $$
#
# 4. **For j(x) = sin(x):**
# $$
# j(2) = \sin(2) \approx 0.909.
# $$
#
# ![image.png](data:image/png;base64,...)
# 2. Let $f(x) = 3x - 1$ and $g(x) = \sqrt{x}$. Find:
#    - $f(g(x))$
#    - $g(f(x))$
#    - $f(f(x))$
#    - $g(g(x))$
#
# and visualize functions in a single Geogebra notebook.
#
# 1. **Finding f(g(x))**:
# $$
# f(g(x)) = f(√x) = 3(√x) - 1.
# $$
#
# 2. **Finding g(f(x))**:
# $$
# g(f(x)) = g(3x - 1) = √(3x - 1).
# $$
#
# 3. **Finding f(f(x))**:
# $$
# f(f(x)) = f(3x - 1) = 3(3x - 1) - 1 = 9x - 3 - 1 = 9x - 4.
# $$
#
# 4. **Finding g(g(x))**:
# $$
# g(g(x)) = g(√x) = √(√x) = x^{1/4}.
# $$
# ![image.png](data:image/png;base64,...)
#
# 3. Let $f(x) = e^x$ and $g(x) = \ln(x)$. Check: $f(g(x))$ and $g(f(x))$. What do you notice?
#
# 1. **Finding f(g(x)):**
# $$
# f(g(x)) = f(ln(x)) = e^{ln(x)}.
# $$
# Using the property e^{ln(x)} = x, we have:
# $$
# f(g(x)) = x.
# $$
#
# 2. **Finding g(f(x)):**
# $$
# g(f(x)) = g(e^x) = ln(e^x).
# $$
# Using the property ln(e^x) = x, we have:
# $$
# g(f(x)) = x.
# $$
#
# Both compositions f(g(x)) and g(f(x)) simplify to x. This means:
# $$
# f(g(x)) = x \quad \text{and} \quad g(f(x)) = x.
# $$
#
# ### What Do We Notice?
# This indicates that f(x) and g(x) are inverse functions of each other. When we compose an exponential function e^x with its natural logarithm ln(x), we get back the original input x. The same is true when we compose ln(x) with e^x. This is a key property of inverse functions:
#
# $$
# f(g(x)) = g(f(x)) = x.
# $$
#
#
# 4. We have function $f=\{(1,7), (2,9), (3,11)\}$. Give inverse function $f^{-1}$.
#
# - Swap (1, 7) to get (7, 1)
# - Swap (2, 9) to get (9, 2)
# - Swap (3, 11) to get (11, 3)
#
# ### Inverse Function:
# $$
# f^(-1) = \{(7, 1), (9, 2), (11, 3)\}
# $$
#
#
#
#
# 5. We have function $f=\{(1,7), (2,7), (3,11)\}$. Give inverse function $f^{-1}$.
#
# Since the function is not one-to-one, it does not have an inverse. For a function to have an inverse, every output must map to only one input. Since `7` is associated with two different inputs (`1` and `2`), \( f^{-1} \) does not exist.
#
# 6. We have function $f(x)= x-1$. Give inverse function $f^{-1}$. Show both functions on the same Geogebra notebook.
#
#
# $$
# y = x - 1
# $$
#
# $$
# x = y - 1
# $$
#
# $$
# y = x + 1
# $$
#
#
# $$
# f^{-1}(x) = x + 1
# $$
#
# ![image.png](data:image/png;base64,...)
