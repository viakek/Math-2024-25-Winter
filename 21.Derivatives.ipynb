# %% [markdown]
# <a href="https://colab.research.google.com/github/viakek/Math-2024-25-Winter/blob/main/Derivatives.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 21. Derivatives
#
# 1. Compute derivatives of functions:
#    * $y(x) = -3x+3$
#    $$
#    y'(x)=(-3x)'+(3)' \\ y'(x) = -3
#    $$
#    * $y(x) = \pi x + \sin(1)$
#    $$
#    y'(x)= (\pi)' + (sin(1))'= \\ y'(x) = \pi
#    $$
#
#    * $y(x) = 4+\sin(2)$
#    $$
#   y'(x)= (4)'+ (sin(2))'= \\ y'(x) = 0
#    $$
#    * $y(x) = 2x^3 - 3x^2 + 8x - 9$
#    $$
#    y'(x) = 6x^2 - 6x + 8
#    $$
#
#    * $y(x) = 6 x^{1/3}$
#
#     $$
#    y'(x) = \frac{6}{3}x^{-2/3}
#    $$
#
#    * $y(x) = \sqrt{x}$
#    $$
#    y'(x) = x^{1/2}= \frac{1}{2} x^{-1/2}
#    $$
#    * $y(x) = \cos(x) + \sin(x)$
#    $$
#    y'(x) = -\sin(x) + \cos(x)
#    $$
#
#    * $y(x) = 2\sin(x) \cos(x)$
#    $$ sin(x)=u \\ cos(x)=v $$
#    $$ u'v+uv'$$
#    $$ y'(x) = 2(cos(x)cos(x)+sin(x)-sin(x)) $$
#
# $$
# y'(x) = 2(\cos^2(x) - \sin^2(x))
# $$
# $$
# y'(x) = 2\cos(2x)
# $$
#    * $y(x) = x\sin(x)$
#    $$ x=u \\ sin(x)=v $$
#    $$ y'(x) = u'v+uv' $$
#    $$ y'(x) = 1*sin(x)+x*cos(x) \\ sin(x)+xcos(x) $$
#
#    * $y(x) = (x+1)(x+1)$
#    $$ (x+1)^{2} = $$
#    $$
# y(x) = x^2 + 2x + 1
# $$
# $$
# y'(x) = 2x + 2
# $$
#    * $y(x) = \frac{x}{x+1}$
#    $$ x=u \\ x+1 = v $$
#    $$ y'(x) = \frac{u'v-uv'}{v^{2}} $$
#    $$
# y'(x) = \frac{(1)(x+1) - x(1)}{(x+1)^2}
# $$
# $$
# y'(x) = \frac{1}{(x+1)^2}
# $$
#    * $y(x) = (x+1)\exp(x)$
#    $$
# y'(x) = \exp(x) + (x+1)\exp(x)
# $$
#    * $y(x) = \sin(x^2)$
#    $$
# y'(x) = \cos(x^2) \cdot \frac{d}{dx}(x^2)
# $$
# $$
# y'(x) = 2x\cos(x^2)
# $$
#    * $y(x) = \exp(-2x)$
#    $$
# y'(x) = \exp(-2x) \cdot \frac{d}{dx}(-2x)
# $$
# $$
# y'(x) = -2\exp(-2x)
# $$
#    * $y(x) = \frac{1}{\sin(x+1)}$
#    $$ y'(x)=(sin(x+1))^{-1} = $$
# $$ y'(x)=-(sin(x+1))^{-2} * cos(x+1) = $$
#    $$
# y'(x) = -\frac{\cos(x+1)}{\sin^2(x+1)}
# $$
#    * $y(x) = \sqrt{2x+1}$
#    $$ y'(x)=(2x+1)^{1/2} = \frac{1}{2}(2x+1)^{-1/2} * 2 = $$
# $$
# y'(x) = \frac{1}{\sqrt{2x+1}}
# $$
# 2. Prove:
#    - $\frac{d}{dx} (\ln(\sin(x))) = \cot(x)$
#    ### Using chain rule
# $$ y'(x)= \frac{1}{sin(x)} *cos(x) $$
# $$ y'(x)= \frac{cos(x)}{sin(x)} = cot(x) $$
# 3. For $f(x) = \cos(x)$, verify that $f''(x) = -f(x)$.
# $$ f'(x)=-sin(x) $$
# $$ f''(x)= -cos(x) $$
# $$ f''(x)=-f(x) $$
#
# 4. Using de l'Hospital's Rule, find the improper limits:
#    - $\displaystyle \lim_{x\to 0} \frac{\sin{x}}{x}$
# $$
# \lim_{x \to 0} \frac{\sin(x)}{x} = \lim_{x \to 0} \frac{\cos(x)}{1} = \cos(0) = 1
# $$
#
# $$
# \lim_{x \to 0} \frac{\sin(x)}{x} = 1.
# $$
#    - $\displaystyle \lim_{x\to \infty} \frac{\ln x}{x}$
# $$
# \lim_{x \to \infty} \frac{\ln(x)}{x} = \lim_{x \to \infty} \frac{\frac{1}{x}}{1} = \lim_{x \to \infty} \frac{1}{x} = 0
# $$
#
# $$
# \lim_{x \to \infty} \frac{\ln(x)}{x} = 0.
# $$
#    - $\displaystyle \lim_{x\to \infty} \frac{\exp(x)}{x}$
# $$
# \lim_{x \to \infty} \frac{e^x}{x} = \lim_{x \to \infty} \frac{e^x}{1} = \infty
# $$
#
# $$
# \lim_{x \to \infty} \frac{e^x}{x} = \infty.
# $$
# 5. In physics, the position of a particle is given by $x(t) = 3t^2 - 6t + 1$. Find the velocity $V(t)=x'(t)$ and acceleration $a(t)=V'(t)=x''(t)$ of the particle at time $t = 2$.
#
# $$ velocity=v(t)=x'(t) $$
# $$ x'(t)= 6t-6 $$
# $$ acceleration= a(t)=x''(t) $$
# $$ x''(t) = 6 $$
# $$ at \\ t=2 \\ v(t)= 6(2)-6 = 6 \\ a(t) = 6 $$
